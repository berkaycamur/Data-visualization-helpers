# %% [markdown]
# Creating bar charts w seaborn. Idk why but bar charts alwasy forcing me.

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
sns.barplot(x='Product_Category',y='Revenue',data=sales)

# %% [markdown]
# These line of codes provides to stack respectively as side by side.  If number of plots are bigger than the number of rows, plots stacks on the bottom of the previous row.

# %%
fig, axs = plt.subplots(nrows= number_of_rows, ncols=number_of_columns, figsize = (20,10))
index = 0
sns.set_theme(style= "whitegrid")
axs = axs.flatten() # We have to convert axis variable to numpy array.
for i in df.columns:
  sns.plottype(y = df[i], ax= axs[index])
  index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# Creating kde's.

# %%
df = sns.load_dataset('iris')
sns.kdeplot(df['sepal_width'])
plt.show()

# %% [markdown]
# Creating grouped bar charts

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# create a dataset
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, height, color=['black', 'red', 'green', 'blue', 'cyan'])

# Create names on the x-axis
plt.xticks(x_pos, bars)

# Show graph
plt.show()
